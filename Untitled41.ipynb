# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashLam/aviansh_portfolio/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3],complex)
a
# Out:
# array([1.+0.j, 2.+0.j, 3.+0.j])

# %%
import numpy as np
a=np.array([[1,2,3],[2,3,4]])
print(a[1,1:3])

print(a.ndim)
# Out:
# [3 4]
# 2

# %%
import numpy as np
a=np.array([[[1,2,3],[2,3,4]],[[2,3,4],[5,6,7]]])
print(a.dtype)
print(a.shape)
print(a.size)
print(a.ndim)
a.reshape(4,3)
a.itemsize
a[0,1,2]
# Out:
# int64
# (2, 2, 3)
# 12
# 3
# 4

# %%
import numpy as np
a=np.empty((3,2),dtype=float,order='C')
a
# Out:
# array([[3.90895885e-316, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000]])

# %%
import numpy as np
a=b"words"
c=np.frombuffer(a,count=3,offset=2,dtype='S1')
c
# Out:
# array([b'r', b'd', b's'], dtype='|S1')

# %%
import numpy as np
a=np.array([[1,2,3],[3,4,5]])
for i in np.nditer(a):
  print(i)
# Out:
# 1
# 2
# 3
# 3
# 4
# 5
